# %% [markdown]
# ## EXERCICÍOS

# %%
import pandas as pd

# %%
caminho = '30_arquivos/Base_Dados_Autorizacoes_Embarcacoes_Pesca.csv'
autorizacoes_df = pd.read_csv(caminho, sep=';', encoding='latin-1')
display(autorizacoes_df)
# Out:
#       Nome da Embarcacao Numero de Inscricao no RGP  \
# 0                      7                 RJ00070751
# 1                      7                 CE00253345
# 2            02 DE JULHO                 CE00033717
# 3              03 IRMAOS                 AP00244798
# 4              03 IRMÃOS                 BA00002978
# ...                  ...                        ...
# 25744                ZUT                 AL00287586
# 25745    Z. VAL PESCADOS                 SC00068350
# 25746      ZVAL PESCADOS                 SC00177610
# 25747         HENRIQUE I                 CE00102007
# 25748  PATRICIO SILVEIRA                 CE00327975
#
#       Numero de Inscricao na Marinha do Brasil    AB Comprimento    Propulsao  \
# 0                                   3870058803     7        10,2        Motor
# 1                               161M2013001190   NaN        4,13  Motor, Vela
# 2                                   1620022150   0,9         5,3         Vela
# ...
