# %%
import pandas as pd

# %%
dados_df = pd.read_csv('pesquisas_microdados.csv')
display(dados_df)
# Out:
#         id_pesquisa   ano sigla_uf nome_municipio       cargo        data  \
# 0              8023  2006      NaN            NaN  presidente  2006-09-19
# 1              8023  2006      NaN            NaN  presidente  2006-09-19
# 2              8023  2006      NaN            NaN  presidente  2006-09-19
# 3              8023  2006      NaN            NaN  presidente  2006-09-19
# 4              8023  2006      NaN            NaN  presidente  2006-09-19
# ...             ...   ...      ...            ...         ...         ...
# 166287        10531  2022      NaN            NaN  presidente  2022-09-02
# 166288        10531  2022      NaN            NaN  presidente  2022-09-02
# 166289        10531  2022      NaN            NaN  presidente  2022-09-02
# 166290        10531  2022      NaN            NaN  presidente  2022-09-02
# 166291        10531  2022      NaN            NaN  presidente  2022-09-02
#
#           data_referencia  instituto contratante orgao_registro  ...  \
# ...

# %%
dados_df = dados_df.dropna()
display(dados_df)
# Out:
#         id_pesquisa   ano sigla_uf nome_municipio     cargo        data  \
# 16903          4892  2004       AM         Manaus  prefeito  2004-08-11
# 16904          4892  2004       AM         Manaus  prefeito  2004-08-11
# 16906          4892  2004       AM         Manaus  prefeito  2004-08-11
# 16907          4892  2004       AM         Manaus  prefeito  2004-08-11
# 16908          4892  2004       AM         Manaus  prefeito  2004-08-11
# ...             ...   ...      ...            ...       ...         ...
# 166164         6706  2012       CE      Fortaleza  prefeito  2012-10-24
# 166167         6712  2012       PR       Curitiba  prefeito  2012-10-24
# 166169         6712  2012       PR       Curitiba  prefeito  2012-10-24
# 166170         6715  2012       SP      São Paulo  prefeito  2012-10-24
# 166171         6715  2012       SP      São Paulo  prefeito  2012-10-24
#
#        data_referencia   instituto            contratante     orgao_registro  \
# ...
