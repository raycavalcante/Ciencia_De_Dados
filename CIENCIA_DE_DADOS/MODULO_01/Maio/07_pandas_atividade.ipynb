# %% [markdown]
# ## Atividade rapida

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
caminho = '07_arquivos/portal_dados_climaticos.csv'

dados_df = pd.read_csv(caminho, sep=';', encoding='utf-8', low_memory=False)

# %%
display(dados_df)
# Out:
#             Data  Hora (UTC) Temp. Ins. (C) Temp. Max. (C) Temp. Min. (C)  \
# 0     01/05/2024           0            NaN            NaN            NaN
# 1     01/05/2024         100            NaN            NaN            NaN
# 2     01/05/2024         200            NaN            NaN            NaN
# 3     01/05/2024         300            NaN            NaN            NaN
# 4     01/05/2024         400            NaN            NaN            NaN
# ...          ...         ...            ...            ...            ...
# 2971  01/09/2024        1900            NaN            NaN            NaN
# 2972  01/09/2024        2000            NaN            NaN            NaN
# 2973  01/09/2024        2100            NaN            NaN            NaN
# 2974  01/09/2024        2200            NaN            NaN            NaN
# 2975  01/09/2024        2300            NaN            NaN            NaN
#
#      Umi. Ins. (%) Umi. Max. (%) Umi. Min. (%) Pto Orvalho Ins. (C)  \
# ...

# %%
dados_df = dados_df.dropna()
display(dados_df)
# Out:
#            Data  Hora (UTC) Temp. Ins. (C) Temp. Max. (C) Temp. Min. (C)  \
# 13   01/05/2024        1300           29,8           30,2           27,9
# 14   01/05/2024        1400           29,8           30,2           29,4
# 15   01/05/2024        1500           31,0           31,1           29,8
# 16   01/05/2024        1600           30,1           32,2           30,1
# 17   01/05/2024        1700           31,2           31,9           30,1
# 18   01/05/2024        1800           31,0           31,5           30,4
# 19   01/05/2024        1900           30,2           31,1           29,9
# 20   01/05/2024        2000           29,3           30,2           28,9
# 37   02/05/2024        1300           29,6           30,4           29,1
# 38   02/05/2024        1400           30,6           31,1           29,5
# 39   02/05/2024        1500           29,8           30,9           29,1
# 40   02/05/2024        1600           30,7           31,1           29,8
# ...

# %% [markdown]
# # Pesquisa

# %%
caminho = '07_arquivos/estacao_dados.csv'

estacao_df = pd.read_csv(caminho, sep=';', encoding='utf-8', low_memory=False)

# %%
display(estacao_df)
# Out:
#             Data  Hora (UTC) Temp. Ins. (C) Temp. Max. (C) Temp. Min. (C)  \
# 0     01/05/2024           0           27,6           27,9           27,5
# 1     01/05/2024         100           27,2           27,7           27,1
# 2     01/05/2024         200           26,6           27,5           26,6
# 3     01/05/2024         300           26,4           26,6           26,3
# 4     01/05/2024         400           26,5           26,5           26,3
# ...          ...         ...            ...            ...            ...
# 2971  01/09/2024        1900            NaN            NaN            NaN
# 2972  01/09/2024        2000            NaN            NaN            NaN
# 2973  01/09/2024        2100            NaN            NaN            NaN
# 2974  01/09/2024        2200            NaN            NaN            NaN
# 2975  01/09/2024        2300            NaN            NaN            NaN
#
#      Umi. Ins. (%) Umi. Max. (%) Umi. Min. (%) Pto Orvalho Ins. (C)  \
# ...
